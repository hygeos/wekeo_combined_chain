# %%
from pathlib import Path
from datetime import date

from wekeo_combined_chain.combined import get_combined_product, save_combined_product

s5p_pca_test_file = Path("/mnt/ceph/proj/WEKEO/S5P_PCA_V0.1") / "S5P-PCA-BD7_2021-08-01_v0.1.nc"

day = date(2021, 8, 1)

# ds = get_combined_product(s5p_pca_test_file)
ds = get_combined_product(day=day)

save_combined_product(ds)

# %%
# Save the combined dataset to a NetCDF file
